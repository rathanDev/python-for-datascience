# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
fig = plt.figure()

# %%
x = np.linspace(0,5,11)

# %%
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])

# %%
axes1.plot(x,y)

# %%
axes1.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0a6f2616f4b8> in <module>()
# ----> 1 axes1.show()
#
# AttributeError: 'Axes' object has no attribute 'show'

# %%
plt.plot(x,y)

# %%
axes1.plot(x,y)

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
#axes.plot(x,y)

# plt.tight_layout()

# for ax in axes:
#     ax.plot(x,y)

axes[0].plot(x,y)
axes[0].set_title('First Plot')

axes[1].plot(y,x)
axes[1].set_title('Second Plot')
# Out:
# Text(0.5,1,'Second Plot')

# %%
fig = plt.figure(figsize=(8,2))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig, axes = plt.subplots(figsize=(8,2))

len(axes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-94b4282a4211> in <module>()
#       1 fig, axes = plt.subplots(figsize=(8,2))
#       2
# ----> 3 len(axes)
#
# TypeError: object of type 'AxesSubplot' has no len()

# %%
fig, axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig

# %%
fig.savefig('pict.png', dpi=200)

# %%
1
# Out:
# 1

# %%
fi = plt.figure() 
ax = fi.add_axes([0,0,1,1])
ax.plot(x,y)
