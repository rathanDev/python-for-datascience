# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# ** Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
df = pd.read_csv('../resources/Salaries.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
bp = df['BasePay']
bp.mean()
# Out:
# 66325.44884050643

# %% [markdown]
# **What is the average BasePay ?**

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df[df['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
jos_df = df[df['EmployeeName']=='JOSEPH DRISCOLL']
jos_df
# Out:
#     Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 24  31909.28       NaN  270324.91         270324.91  2011    NaN
#
#            Agency  Status
# 24  San Francisco     NaN

# %%
jos_df['TotalPay']
# Out:
# 24    270324.91
# Name: TotalPay, dtype: float64

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
df[df['TotalPay'] == df['TotalPay'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
df[df['TotalPay'] == df['TotalPay'].max()]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
df[df['TotalPay'] == df['TotalPay'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
df[df['TotalPay'] == df['TotalPay'].min()]['EmployeeName']
# Out:
# 148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
df.head(3)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3  ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN

# %%
df['Year'].tail(10)
# Out:
# 148644    2014
# 148645    2014
# 148646    2014
# 148647    2014
# 148648    2014
# 148649    2014
# 148650    2014
# 148651    2014
# 148652    2014
# 148653    2014
# Name: Year, dtype: int64

# %%
df[['Year','BasePay']].groupby('Year').mean()
# Out:
#            BasePay
# Year
# 2011  63595.956517
# 2012  65436.406857
# 2013  69630.030216
# 2014  66564.421924

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# ** How many unique job titles are there? **

# %%
df.groupby(['JobTitle']).count().sort_values('Id', ascending=False).head(5)['Id']
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: Id, dtype: int64

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
len(df.groupby('JobTitle').count().sort_values(by='Id')['Id']==1)
# Out:
# 2159

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df[df['Year']==2013].groupby('JobTitle').count()['Id']
# Out:
# JobTitle
# ASR Senior Office Specialist      21
# ASR-Office Assistant              15
# Account Clerk                     90
# Accountant I                       3
# Accountant II                     77
#                                   ..
# Wire Rope Cable Maint Sprv         1
# Worker's Comp Supervisor 1         3
# Worker's Compensation Adjuster    25
# X-Ray Laboratory Aide             34
# Youth Comm Advisor                 2
# Name: Id, Length: 1051, dtype: int64

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df[df['Year']==2013].groupby('JobTitle').count()
# Out:
#                                 Id  EmployeeName  BasePay  OvertimePay  \
# JobTitle
# ASR Senior Office Specialist    21            21       21           21
# ASR-Office Assistant            15            15       15           15
# Account Clerk                   90            90       87           90
# Accountant I                     3             3        3            3
# Accountant II                   77            77       77           77
# ...                             ..           ...      ...          ...
# Wire Rope Cable Maint Sprv       1             1        1            1
# Worker's Comp Supervisor 1       3             3        3            3
# Worker's Compensation Adjuster  25            25       25           25
# X-Ray Laboratory Aide           34            34       34           34
# Youth Comm Advisor               2             2        2            2
#
#                                 OtherPay  Benefits  TotalPay  \
# JobTitle
# ...

# %%
sum(df[df['Year']==2013]['JobTitle'].value_counts() == 1) ## prettyTricky
# Out:
# 202

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
sum(df[df['JobTitle'].str.contains('Chief')]['JobTitle'].value_counts())
# Out:
# 423

# %%
job_group = df[df['JobTitle'].str.contains('Chief')]
job_group
# Out:
#             Id         EmployeeName                        JobTitle  \
# 36160    36161         Gregory Suhr                 Chief of Police
# 36162    36163   Joanne Hayes-White          Chief, Fire Department
# 36169    36170         Brendan Ward  Battlion Chief, Fire Suppressi
# 36170    36171           Samson Lai  Battlion Chief, Fire Suppressi
# 36171    36172     Rudy Castellanos  Battlion Chief, Fire Suppressi
# ...        ...                  ...                             ...
# 138011  138012     Sharon C Jackson  Chief Deputy Adlt Probation Of
# 139620  139621          Anita S Lee                     Chief Clerk
# 139709  139710     George D Vaughan        Chief Nursery Specialist
# 140080  140081  Patrick W Gillespie                Chief Preparator
# 140156  140157  Christopher L Ochoa       Chief Stationary Engineer
#
#           BasePay  OvertimePay  OtherPay  Benefits   TotalPay  \
# 36160   302578.00         0.00  18974.11  69810.19  321552.11
# ...

# %%
job_group.groupby('JobTitle').count().head()
# Out:
#                                 Id  EmployeeName  BasePay  OvertimePay  \
# JobTitle
# Assistant Chief Attorney 1      71            71       71           71
# Assistant Chief Attorney 2      18            18       18           18
# Assistant Deputy Chief 2        11            11       11           11
# Battalion Chief, Fire Suppress  65            65       63           65
# Battlion Chief, Fire Suppressi  36            36       36           36
#
#                                 OtherPay  Benefits  TotalPay  \
# JobTitle
# Assistant Chief Attorney 1            71        71        71
# Assistant Chief Attorney 2            18        18        18
# Assistant Deputy Chief 2              11        11        11
# Battalion Chief, Fire Suppress        65        65        65
# Battlion Chief, Fire Suppressi        36        36        36
#
#                                 TotalPayBenefits  Year  Notes  Agency  Status
# JobTitle
# ...

# %%
df[df['JobTitle'].str.contains('Chief')][['EmployeeName','JobTitle']].groupby('JobTitle').count()
# Out:
#                                 EmployeeName
# JobTitle
# Assistant Chief Attorney 1                71
# Assistant Chief Attorney 2                18
# Assistant Deputy Chief 2                  11
# Battalion Chief, Fire Suppress            65
# Battlion Chief, Fire Suppressi            36
# Chief Adult Probation Officer              3
# Chief Atty1 (Civil & Criminal)            14
# Chief Building Inspector                  12
# Chief Clerk                               45
# Chief Dep Adlt Prob Of (SFERS)             3
# Chief Deputy Adlt Probation Of             4
# Chief Deputy Sheriff                      10
# Chief Dietitian                            5
# Chief Electrical Inspector                 3
# Chief Fire Alarm Dispatcher                3
# Chief Forensic Toxicologist                1
# Chief Housing Inspector                    3
# Chief Investment Officer                   1
# Chief Nursery Specialist                   3
# Chief Plumbing Inspector                   3
# ...

# %%
def get_chief(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

# %%
# sum(df['JobTitle'].apply(lambda x: get_chief(x))) #627
sum(df['JobTitle'].apply(get_chief)) #627
# Out:
# 627

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) ** 477

# %%
df.head(3)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3  ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN

# %%
df['title_len'] = df['JobTitle'].apply(len)
df.head(3)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3  ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
#
#    Year  Notes         Agency  Status  title_len
# 0  2011    NaN  San Francisco     NaN         46
# 1  2011    NaN  San Francisco     NaN         31
# 2  2011    NaN  San Francisco     NaN         31

# %%
df[['title_len','BasePay']].corr()
# Out:
#            title_len   BasePay
# title_len   1.000000 -0.005059
# BasePay    -0.005059  1.000000

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000

# %% [markdown]
# # Great Job!
