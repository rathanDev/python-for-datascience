# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

pd.__version__
# Out:
# '1.0.1'

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %%
tiingo_api_key = '861f29bd8665beb2fda25f6f3474f1feb1096860'
quandl_api_key = 'd5r5zQSW4YrfhoaVjd8K'

# %%
BAC = data.DataReader("BAC", "quandl", start, end, api_key=quandl_api_key)
C = data.DataReader("C", "quandl", start, end, api_key=quandl_api_key)
GS = data.DataReader("GS", "quandl", start, end, api_key=quandl_api_key)
JPM = data.DataReader("JPM", "quandl", start, end, api_key=quandl_api_key)
MS = data.DataReader("MS", "quandl", start, end, api_key=quandl_api_key)
WFC = data.DataReader("WFC", "quandl", start, end, api_key=quandl_api_key)

# %%
BAC.head()
# Out:
#              Open   High    Low  Close      Volume  ExDividend  SplitRatio  \
# Date
# 2015-12-31  17.01  17.07  16.83  16.83  47106760.0         0.0         1.0
# 2015-12-30  17.20  17.24  17.04  17.05  35035518.0         0.0         1.0
# 2015-12-29  17.25  17.35  17.16  17.28  45628449.0         0.0         1.0
# 2015-12-28  17.22  17.23  16.98  17.13  41759993.0         0.0         1.0
# 2015-12-24  17.32  17.38  17.22  17.27  29373415.0         0.0         1.0
#
#               AdjOpen    AdjHigh     AdjLow   AdjClose   AdjVolume
# Date
# 2015-12-31  16.564256  16.622684  16.388973  16.388973  47106760.0
# 2015-12-30  16.749277  16.788229  16.593470  16.603208  35035518.0
# 2015-12-29  16.797967  16.895347  16.710326  16.827181  45628449.0
# 2015-12-28  16.768753  16.778491  16.535042  16.681112  41759993.0
# 2015-12-24  16.866133  16.924561  16.768753  16.817443  29373415.0

# %%
BAC = BAC[['Open', 'High', 'Low', 'Close', 'Volume']]
C = C[['Open', 'High', 'Low', 'Close', 'Volume']]
GS = GS[['Open', 'High', 'Low', 'Close', 'Volume']]
JPM = JPM[['Open', 'High', 'Low', 'Close', 'Volume']]
MS = MS[['Open', 'High', 'Low', 'Close', 'Volume']]
WFC = WFC[['Open', 'High', 'Low', 'Close', 'Volume']]

# %%
BAC.head()
# Out:
#              Open   High    Low  Close      Volume
# Date
# 2015-12-31  17.01  17.07  16.83  16.83  47106760.0
# 2015-12-30  17.20  17.24  17.04  17.05  35035518.0
# 2015-12-29  17.25  17.35  17.16  17.28  45628449.0
# 2015-12-28  17.22  17.23  16.98  17.13  41759993.0
# 2015-12-24  17.32  17.38  17.22  17.27  29373415.0

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
banks_stocks = pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)

# %%
banks_stocks.head()
# Out:
#               BAC                                       C                \
#              Open   High    Low  Close      Volume   Open   High    Low
# Date
# 2015-12-31  17.01  17.07  16.83  16.83  47106760.0  52.07  52.39  51.75
# 2015-12-30  17.20  17.24  17.04  17.05  35035518.0  52.84  52.94  52.25
# 2015-12-29  17.25  17.35  17.16  17.28  45628449.0  52.76  53.22  52.74
# 2015-12-28  17.22  17.23  16.98  17.13  41759993.0  52.57  52.57  51.96
# 2015-12-24  17.32  17.38  17.22  17.27  29373415.0  52.48  52.97  52.45
#
#                                ...     MS                                     \
#             Close      Volume  ...   Open     High     Low  Close     Volume
# Date                           ...
# 2015-12-31  51.75  11274831.0  ...  31.91  32.3000  31.770  31.81  8149307.0
# 2015-12-30  52.30   8763137.0  ...  32.50  32.6450  32.200  32.23  5057162.0
# 2015-12-29  52.98  10153534.0  ...  32.44  32.7016  32.325  32.55  6388244.0
# ...

# %%
# Out:
#              Open   High    Low  Close      Volume  ExDividend  SplitRatio  \
# Date
# 2015-12-31  17.01  17.07  16.83  16.83  47106760.0         0.0         1.0
# 2015-12-30  17.20  17.24  17.04  17.05  35035518.0         0.0         1.0
# 2015-12-29  17.25  17.35  17.16  17.28  45628449.0         0.0         1.0
# 2015-12-28  17.22  17.23  16.98  17.13  41759993.0         0.0         1.0
# 2015-12-24  17.32  17.38  17.22  17.27  29373415.0         0.0         1.0
#
#               AdjOpen    AdjHigh     AdjLow   AdjClose   AdjVolume
# Date
# 2015-12-31  16.564256  16.622684  16.388973  16.388973  47106760.0
# 2015-12-30  16.749277  16.788229  16.593470  16.603208  35035518.0
# 2015-12-29  16.797967  16.895347  16.710326  16.827181  45628449.0
# 2015-12-28  16.768753  16.778491  16.535042  16.681112  41759993.0
# 2015-12-24  16.866133  16.924561  16.768753  16.817443  29373415.0

# %%
banks_stocks.columns.names = ['Bank Ticker', 'Stock Info']

# %%
banks_stocks.head()
# Out:
# Bank Ticker    BAC                                                         \
# Stock Info    Open   High    Low  Close      Volume ExDividend SplitRatio
# Date
# 2015-12-31   17.01  17.07  16.83  16.83  47106760.0        0.0        1.0
# 2015-12-30   17.20  17.24  17.04  17.05  35035518.0        0.0        1.0
# 2015-12-29   17.25  17.35  17.16  17.28  45628449.0        0.0        1.0
# 2015-12-28   17.22  17.23  16.98  17.13  41759993.0        0.0        1.0
# 2015-12-24   17.32  17.38  17.22  17.27  29373415.0        0.0        1.0
#
# Bank Ticker                                   ...     WFC                     \
# Stock Info     AdjOpen    AdjHigh     AdjLow  ...     Low  Close      Volume
# Date                                          ...
# 2015-12-31   16.564256  16.622684  16.388973  ...  54.220  54.36  10929420.0
# 2015-12-30   16.749277  16.788229  16.593470  ...  54.794  54.89   8016893.0
# 2015-12-29   16.797967  16.895347  16.710326  ...  54.990  55.29   7894876.0
# ...

# %%
# EDA - Exploratory Data Analysis

# %%
for tick in tickers:
    print(tick, banks_stocks[tick]['Close'].max())
# Out:
# BAC 54.9
# C 60.34
# GS 247.92
# JPM 70.08
# MS 89.3
# WFC 73.0

# %%
# Using Pandas

# %%
banks_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C       60.34
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     73.00
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick + ' Return'] = banks_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2015-12-31         NaN       NaN        NaN         NaN        NaN         NaN
# 2015-12-30    0.013072  0.010628   0.009876    0.008481   0.013203    0.009750
# 2015-12-29    0.013490  0.013002   0.008351    0.007208   0.009929    0.007287
# 2015-12-28   -0.008681 -0.011325  -0.010407   -0.010288  -0.011674   -0.011033
# 2015-12-24    0.008173  0.006300   0.004680    0.003314   0.009636    0.002560

# %%
sns.pairplot(returns)

# %%
sns.pairplot(returns[1:])

# %%
# Part 2

# %%
 returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2015-12-31         NaN       NaN        NaN         NaN        NaN         NaN
# 2015-12-30    0.013072  0.010628   0.009876    0.008481   0.013203    0.009750
# 2015-12-29    0.013490  0.013002   0.008351    0.007208   0.009929    0.007287
# 2015-12-28   -0.008681 -0.011325  -0.010407   -0.010288  -0.011674   -0.011033
# 2015-12-24    0.008173  0.006300   0.004680    0.003314   0.009636    0.002560

# %%
returns.min()
# Out:
# BAC Return   -0.260733
# C Return     -0.897645
# GS Return    -0.209285
# JPM Return   -0.200619
# MS Return    -0.465193
# WFC Return   -0.246787
# dtype: float64

# %%
returns['BAC Return'].argmin()
# Out:
# 1695

# %%
returns.idxmin()
# Out:
# BAC Return   2009-04-08
# C Return     2011-05-06
# GS Return    2008-11-21
# JPM Return   2009-01-20
# MS Return    2008-10-10
# WFC Return   2008-07-15
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-01-16
# C Return     2009-02-26
# GS Return    2009-01-16
# JPM Return   2009-01-16
# MS Return    2008-10-08
# WFC Return   2006-08-11
# dtype: datetime64[ns]

# %%
-- Standard Deviations

# %%
returns.std()
# Out:
# BAC Return    0.037062
# C Return      0.043327
# GS Return     0.025155
# JPM Return    0.027392
# MS Return     0.035599
# WFC Return    0.035655
# dtype: float64

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2015-12-31         NaN       NaN        NaN         NaN        NaN         NaN
# 2015-12-30    0.013072  0.010628   0.009876    0.008481   0.013203    0.009750
# 2015-12-29    0.013490  0.013002   0.008351    0.007208   0.009929    0.007287
# 2015-12-28   -0.008681 -0.011325  -0.010407   -0.010288  -0.011674   -0.011033
# 2015-12-24    0.008173  0.006300   0.004680    0.003314   0.009636    0.002560

# %%
returns.ix['2015-01-01':'2015-12-31'].std()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-05381c1bc8cc> in <module>
# ----> 1 returns.ix['2015-01-01':'2015-12-31'].std()
#
# C:\Installations\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
returns['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return   NaN
# C Return     NaN
# GS Return    NaN
# JPM Return   NaN
# MS Return    NaN
# WFC Return   NaN
# dtype: float64

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick,figsize=(12,4))

plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-972f51d8a24f> in <module>
#       1 for tick in tickers:
# ----> 2     bank_stocks[tick]['Close'].plot(label=tick,figsize=(12,4))
#       3
#       4 plt.legend()
#
# NameError: name 'bank_stocks' is not defined

# %%
banks_stocks.head()
# Out:
# Bank Ticker    BAC                                                         \
# Stock Info    Open   High    Low  Close      Volume ExDividend SplitRatio
# Date
# 2015-12-31   17.01  17.07  16.83  16.83  47106760.0        0.0        1.0
# 2015-12-30   17.20  17.24  17.04  17.05  35035518.0        0.0        1.0
# 2015-12-29   17.25  17.35  17.16  17.28  45628449.0        0.0        1.0
# 2015-12-28   17.22  17.23  16.98  17.13  41759993.0        0.0        1.0
# 2015-12-24   17.32  17.38  17.22  17.27  29373415.0        0.0        1.0
#
# Bank Ticker                                   ...     WFC                     \
# Stock Info     AdjOpen    AdjHigh     AdjLow  ...     Low  Close      Volume
# Date                                          ...
# 2015-12-31   16.564256  16.622684  16.388973  ...  54.220  54.36  10929420.0
# 2015-12-30   16.749277  16.788229  16.593470  ...  54.794  54.89   8016893.0
# 2015-12-29   16.797967  16.895347  16.710326  ...  54.990  55.29   7894876.0
# ...

# %%
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for tick in tickers:
    banks_stocks[tick]['Close'].plot(label=tick, figsize=(12,4))
    
plt.legend()

# %%
banks_stocks.xs(key='Close',axis=1,level='Stock Info').plot()

# %%
banks_stocks.xs(key='Close',axis=1, level='Stock Info').iplot()
# Out:
# <div>
#
#
#             <div id="c5438121-2286-401b-9f32-3130da44e00f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c5438121-2286-401b-9f32-3130da44e00f")) {
#                     Plotly.newPlot(
#                         'c5438121-2286-401b-9f32-3130da44e00f',
# ...

# %%
corr = banks_stocks.xs(key='Close',axis=1,level='Stock Info').corr()
sns.heatmap(corr, annot=True)

# %%
sns.clustermap(corr, annot=True)

# %%
# Part 3

# %%
# Optional section

# %%
close_corr = corr
close_corr.head()
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS       WFC
# Bank Ticker
# BAC          1.000000  0.363303  0.550936  0.103855  0.944219  0.276687
# C            0.363303  1.000000  0.426868  0.700735  0.449794  0.723474
# GS           0.550936  0.426868  1.000000  0.685347  0.683830  0.359021
# JPM          0.103855  0.700735  0.685347  1.000000  0.250410  0.697574
# MS           0.944219  0.449794  0.683830  0.250410  1.000000  0.331510

# %%
close_corr.iplot(kind='heatmap', colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="2fb830e9-348c-49e7-83ea-e25b9c6569c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2fb830e9-348c-49e7-83ea-e25b9c6569c4")) {
#                     Plotly.newPlot(
#                         '2fb830e9-348c-49e7-83ea-e25b9c6569c4',
# ...

# %%
BAC.head()
# Out:
#              Open   High    Low  Close      Volume
# Date
# 2015-12-31  17.01  17.07  16.83  16.83  47106760.0
# 2015-12-30  17.20  17.24  17.04  17.05  35035518.0
# 2015-12-29  17.25  17.35  17.16  17.28  45628449.0
# 2015-12-28  17.22  17.23  16.98  17.13  41759993.0
# 2015-12-24  17.32  17.38  17.22  17.27  29373415.0
